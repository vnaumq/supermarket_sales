# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

path_to_file = r'D:\university\VSCODE\project\Supermarket_sales\supermarket_sales.csv'
# Out:
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_12760\1330891929.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv(path_to_file)
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# 50%                   4.761905     12.088000     7.00000
# 75%                   4.761905     22.445250     8.50000
# max                   4.761905     49.650000    10.00000

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Time'] = pd.to_datetime(df['Time'])
df.dtypes
# Out:
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_12760\2964515701.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
def rename_columns(name):
    new_name = name.lower().replace(' ','_')
    return new_name

# %%
df.rename(columns= rename_columns,inplace=True)

# %%
df
# Out:
#       invoice_id branch       city customer_type  gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                product_line  unit_price  quantity   tax_5%      total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           date                time      payment    cogs  \
# 0   2019-01-05 2024-03-15 13:08:00      Ewallet  522.83
# 1   2019-03-08 2024-03-15 10:29:00         Cash   76.40
# 2   2019-03-03 2024-03-15 13:23:00  Credit card  324.31
# 3   2019-01-27 2024-03-15 20:33:00      Ewallet  465.76
# 4   2019-02-08 2024-03-15 10:37:00      Ewallet  604.17
# ..         ...                 ...          ...     ...
# 995 2019-01-29 2024-03-15 13:46:00      Ewallet   40.35
# 996 2019-03-02 2024-03-15 17:16:00      Ewallet  973.80
# 997 2019-02-09 2024-03-15 13:22:00         Cash   31.84
# 998 2019-02-22 2024-03-15 15:33:00         Cash   65.82
# 999 2019-02-18 2024-03-15 13:28:00         Cash  618.38
#
#      gross_margin_percentage  gross_income  rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ..                       ...           ...     ...
# 995                 4.761905        2.0175     6.2
# 996                 4.761905       48.6900     4.4
# 997                 4.761905        1.5920     7.7
# 998                 4.761905        3.2910     4.1
# 999                 4.761905       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
df1 = df[['city','gender','total','date','payment','time','product_line']]
df1['month'] = pd.DatetimeIndex(df1['date']).month_name()
df1['weekday'] = pd.DatetimeIndex(df1['date']).day_name()
df1['weekday_number'] = pd.DatetimeIndex(df1['date']).weekday
df1['hour'] = pd.DatetimeIndex(df1['time']).hour

df1
# Приведение даты в месяц и в день недели
# Out:
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_12760\957090422.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['month'] = pd.DatetimeIndex(df1['date']).month_name()
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_12760\957090422.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['weekday'] = pd.DatetimeIndex(df1['date']).day_name()
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_12760\957090422.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['weekday_number'] = pd.DatetimeIndex(df1['date']).weekday
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_12760\957090422.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['hour'] = pd.DatetimeIndex(df1['time']).hour
#           city  gender      total       date      payment                time  \
# 0       Yangon  Female   548.9715 2019-01-05      Ewallet 2024-03-15 13:08:00
# 1    Naypyitaw  Female    80.2200 2019-03-08         Cash 2024-03-15 10:29:00
# 2       Yangon    Male   340.5255 2019-03-03  Credit card 2024-03-15 13:23:00
# 3       Yangon    Male   489.0480 2019-01-27      Ewallet 2024-03-15 20:33:00
# 4       Yangon    Male   634.3785 2019-02-08      Ewallet 2024-03-15 10:37:00
# ..         ...     ...        ...        ...          ...                 ...
# 995  Naypyitaw    Male    42.3675 2019-01-29      Ewallet 2024-03-15 13:46:00
# 996   Mandalay  Female  1022.4900 2019-03-02      Ewallet 2024-03-15 17:16:00
# 997     Yangon    Male    33.4320 2019-02-09         Cash 2024-03-15 13:22:00
# 998     Yangon    Male    69.1110 2019-02-22         Cash 2024-03-15 15:33:00
# 999     Yangon  Female   649.2990 2019-02-18         Cash 2024-03-15 13:28:00
#
#                product_line     month   weekday  weekday_number  hour
# 0         Health and beauty   January  Saturday               5    13
# 1    Electronic accessories     March    Friday               4    10
# 2        Home and lifestyle     March    Sunday               6    13
# 3         Health and beauty   January    Sunday               6    20
# 4         Sports and travel  February    Friday               4    10
# ..                      ...       ...       ...             ...   ...
# 995       Health and beauty   January   Tuesday               1    13
# 996      Home and lifestyle     March  Saturday               5    17
# 997      Food and beverages  February  Saturday               5    13
# 998      Home and lifestyle  February    Friday               4    15
# 999     Fashion accessories  February    Monday               0    13
#
# [1000 rows x 11 columns]

# %%
gender_sum = df1.groupby(['gender'],as_index=False).agg({'total':'sum'}).rename(columns={'total':'sum'})

# %%
gender_sum
# Out:
#    gender         sum
# 0  Female  167882.925
# 1    Male  155083.824

# %%
city_sum = df1.groupby(['city'],as_index=False).agg({'total':'sum'}).rename(columns={'total':'sum'})

# %%
city_sum.sort_values('sum',ascending=False)
# Out:
#         city          sum
# 1  Naypyitaw  110568.7065
# 2     Yangon  106200.3705
# 0   Mandalay  106197.6720

# %%
sns.histplot(data= df1, x= 'total',)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
df1.describe()
# Out:
#              total                        date                        time  \
# count  1000.000000                        1000                        1000
# mean    322.966749  2019-02-14 00:05:45.600000  2024-03-15 15:24:41.880000
# min      10.678500         2019-01-01 00:00:00         2024-03-15 10:00:00
# 25%     124.422375         2019-01-24 00:00:00         2024-03-15 12:43:00
# 50%     253.848000         2019-02-13 00:00:00         2024-03-15 15:19:00
# 75%     471.350250         2019-03-08 00:00:00         2024-03-15 18:15:00
# max    1042.650000         2019-03-30 00:00:00         2024-03-15 20:59:00
# std     245.885335                         NaN                         NaN
#
#        weekday_number         hour
# count     1000.000000  1000.000000
# mean         3.032000    14.910000
# min          0.000000    10.000000
# 25%          1.000000    12.000000
# 50%          3.000000    15.000000
# 75%          5.000000    18.000000
# max          6.000000    20.000000
# std          1.973543     3.186857

# %%
sns.histplot(df1, x= 'total',  hue="gender",multiple='stack',fill = False)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
df1.groupby('payment',as_index=False).agg({'gender':'count', 'total' : 'sum'}).rename(columns = {'gender' : 'count', 'total' : 'sum'}).sort_values('sum',ascending = False)
# Out:
#        payment  count         sum
# 0         Cash    344  112206.570
# 2      Ewallet    345  109993.107
# 1  Credit card    311  100767.072

# %%
rating_weekday = df1.groupby(['month','weekday','weekday_number'] , as_index= False).agg({'total' : 'sum'}).rename(columns = {'total' : 'revenue'}).sort_values(['month', 'weekday_number'])
rating_weekday
# Out:
#        month    weekday  weekday_number     revenue
# 1   February     Monday               0  13284.9150
# 5   February    Tuesday               1  12666.4020
# 6   February  Wednesday               2  12405.5295
# 4   February   Thursday               3  13173.0585
# 0   February     Friday               4  16802.2890
# 2   February   Saturday               5  12256.1985
# 3   February     Sunday               6  16630.9815
# 8    January     Monday               0  14192.6715
# 12   January    Tuesday               1  21204.5085
# 13   January  Wednesday               2  17808.3780
# 11   January   Thursday               3  19416.3795
# 7    January     Friday               4  11219.4915
# 9    January   Saturday               5  18093.6840
# 10   January     Sunday               6  14356.7550
# 15     March     Monday               0  10421.4915
# 19     March    Tuesday               1  17611.3350
# 20     March  Wednesday               2  13517.2275
# 18     March   Thursday               3  12759.8100
# 14     March     Friday               4  15904.5600
# 16     March   Saturday               5  25770.9270
# 17     March     Sunday               6  13470.1560

# %%
sns.barplot(rating_weekday,x = 'weekday', y = 'revenue', hue = 'month')
# Out:
# <Axes: xlabel='weekday', ylabel='revenue'>

# %%
revenue_hour = df1.groupby(['month','hour'],as_index=False).agg({'total' : 'sum'}).rename(columns={'total':'revenue'})
revenue_hour
# Out:
#        month  hour     revenue
# 0   February    10  10579.0335
# 1   February    11  11118.6600
# 2   February    12   7138.8345
# 3   February    13   7367.8080
# 4   February    14   8531.1450
# 5   February    15  11131.0080
# 6   February    16   8752.0545
# 7   February    17   7833.8400
# 8   February    18   8961.0780
# 9   February    19   9018.1245
# 10  February    20   6787.7880
# 11   January    10  12357.2295
# 12   January    11  12510.2460
# 13   January    12   8767.7415
# 14   January    13  15700.3980
# 15   January    14  10815.3360
# 16   January    15  11798.2305
# 17   January    16   7306.0890
# 18   January    17   7794.7485
# 19   January    18   8467.0635
# 20   January    19  10932.6945
# 21   January    20   9842.0910
# 22     March    10   8485.2180
# 23     March    11   6748.4235
# 24     March    12  10159.3065
# 25     March    13  11655.0210
# 26     March    14  11481.9180
# 27     March    15   8250.2700
# 28     March    16   9168.1800
# 29     March    17   8816.6295
# 30     March    18   8602.1985
# 31     March    19  19748.6940
# 32     March    20   6339.6480

# %%
sns.lineplot(revenue_hour,x='hour',y='revenue',hue='month',style="month")
# Out:
# <Axes: xlabel='hour', ylabel='revenue'>

# %%
what = df1.query('hour == 19 and month == "March"').total.count()
what
# Out:
# 52

# %%
product_revenue = df1.groupby('product_line',as_index=False).agg({'total' : 'sum'}).rename(columns={'total':'revenue'}).sort_values('revenue',ascending=False)
product_revenue.set_index('product_line',inplace=True)
product_revenue
# Out:
#                            revenue
# product_line
# Food and beverages      56144.8440
# Sports and travel       55122.8265
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Home and lifestyle      53861.9130
# Health and beauty       49193.7390

# %%
product_revenue.plot.pie(y='revenue',figsize=(8,8))
# Out:
# <Axes: ylabel='revenue'>

# %%
fig, ax = plt.subplots()
ax.pie(product_revenue.revenue, labels=product_revenue.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x267b2f3c680>,
#   <matplotlib.patches.Wedge at 0x267b2f3c590>,
#   <matplotlib.patches.Wedge at 0x267b2f3d040>,
#   <matplotlib.patches.Wedge at 0x267b2f3d640>,
#   <matplotlib.patches.Wedge at 0x267b2f3dc10>,
#   <matplotlib.patches.Wedge at 0x267b2f3e240>],
#  [Text(0.9399907865232462, 0.5713294332094306, 'Food and beverages'),
#   Text(-0.06340678822092591, 1.0981710154650353, 'Sports and travel'),
#   Text(-0.9912710276469388, 0.4768456246499302, 'Electronic accessories'),
#   Text(-0.9025960654028014, -0.6287450538329363, 'Fashion accessories'),
#   Text(0.0986710869916935, -1.0955656149185578, 'Home and lifestyle'),
#   Text(0.9764441324952551, -0.5065144184676176, 'Health and beauty')],
#  [Text(0.5127222471944979, 0.3116342362960531, '17.4%'),
#   Text(-0.03458552084777776, 0.5990023720718374, '17.1%'),
#   Text(-0.5406932878074211, 0.26009761344541643, '16.8%'),
#   Text(-0.49232512658334615, -0.342951847545238, '16.8%'),
#   Text(0.05382059290456008, -0.5975812445010314, '16.7%'),
#   Text(0.5326058904519573, -0.27628059189142773, '15.2%')])

# %%
explode = (0.07, 0.07, 0.07, 0.07, 0.07, 0.07)
fig, ax = plt.subplots()
ax.pie(product_revenue.revenue, labels=product_revenue.index, autopct='%1.1f%%', explode=explode,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x267b38add60>,
#   <matplotlib.patches.Wedge at 0x267b3829af0>,
#   <matplotlib.patches.Wedge at 0x267b38ae750>,
#   <matplotlib.patches.Wedge at 0x267b38aecf0>,
#   <matplotlib.patches.Wedge at 0x267b38af2f0>,
#   <matplotlib.patches.Wedge at 0x267b38af920>],
#  [Text(-0.6076867607773033, 0.9998083820292709, 'Food and beverages'),
#   Text(-1.168054625540083, -0.06744176565316658, 'Sports and travel'),
#   Text(-0.5071903462185622, -1.0543519112244712, 'Electronic accessories'),
#   Text(0.6687561027132146, -0.9600339968375249, 'Fashion accessories'),
#   Text(1.1652834267770114, 0.10495015616389208, 'Home and lifestyle'),
#   Text(0.5387471541882842, 1.0385814863813168, 'Health and beauty')],
#  [Text(-0.3479915638639258, 0.5725398427005226, '17.4%'),
#   Text(-0.6688859821468851, -0.038620498280018456, '17.1%'),
#   Text(-0.2904423350140484, -0.6037741713849536, '16.8%'),
#   Text(0.38296289642551595, -0.5497630580180698, '16.8%'),
#   Text(0.6672990563594852, 0.06009966207675871, '16.7%'),
#   Text(0.3085133276120944, 0.594743244338019, '15.2%')])
