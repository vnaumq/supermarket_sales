# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

path_to_file = r'D:\university\VSCODE\project\Supermarket_sales\supermarket_sales.csv'
# Out:
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11088\1330891929.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv(path_to_file)
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# 0     1/5/2019  13:08      Ewallet  522.83                 4.761905
# 1     3/8/2019  10:29         Cash   76.40                 4.761905
# 2     3/3/2019  13:23  Credit card  324.31                 4.761905
# 3    1/27/2019  20:33      Ewallet  465.76                 4.761905
# 4     2/8/2019  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995  1/29/2019  13:46      Ewallet   40.35                 4.761905
# 996   3/2/2019  17:16      Ewallet  973.80                 4.761905
# 997   2/9/2019  13:22         Cash   31.84                 4.761905
# 998  2/22/2019  15:33         Cash   65.82                 4.761905
# 999  2/18/2019  13:28         Cash  618.38                 4.761905
#
#      gross income  Rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# 25%                   4.761905      5.924875     5.50000
# 50%                   4.761905     12.088000     7.00000
# 75%                   4.761905     22.445250     8.50000
# max                   4.761905     49.650000    10.00000

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
def rename_columns(name):
    new_name = name.lower().replace(' ','_')
    return new_name

# %%
df.rename(columns= rename_columns,inplace=True)

# %%
df
# Out:
#       invoice_id branch       city customer_type  gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                product_line  unit_price  quantity   tax_5%      total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           date   time      payment    cogs  gross_margin_percentage  \
# 0   2019-01-05  13:08      Ewallet  522.83                 4.761905
# 1   2019-03-08  10:29         Cash   76.40                 4.761905
# 2   2019-03-03  13:23  Credit card  324.31                 4.761905
# 3   2019-01-27  20:33      Ewallet  465.76                 4.761905
# 4   2019-02-08  10:37      Ewallet  604.17                 4.761905
# ..         ...    ...          ...     ...                      ...
# 995 2019-01-29  13:46      Ewallet   40.35                 4.761905
# 996 2019-03-02  17:16      Ewallet  973.80                 4.761905
# 997 2019-02-09  13:22         Cash   31.84                 4.761905
# 998 2019-02-22  15:33         Cash   65.82                 4.761905
# 999 2019-02-18  13:28         Cash  618.38                 4.761905
#
#      gross_income  rating
# 0         26.1415     9.1
# 1          3.8200     9.6
# 2         16.2155     7.4
# 3         23.2880     8.4
# 4         30.2085     5.3
# ..            ...     ...
# 995        2.0175     6.2
# 996       48.6900     4.4
# 997        1.5920     7.7
# 998        3.2910     4.1
# 999       30.9190     6.6
#
# [1000 rows x 17 columns]

# %%
df1 = df[['city','unit_price','customer_type','gender','total','payment','date']]
df1['month'] = pd.DatetimeIndex(df1['date']).month_name()
df1['weekday'] = pd.DatetimeIndex(df1['date']).day_name()
df1['weekday_number'] = pd.DatetimeIndex(df1['date']).weekday
df1
# Приведение даты в месяц и в день недели
# Out:
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11088\1277653125.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['month'] = pd.DatetimeIndex(df1['date']).month_name()
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11088\1277653125.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['weekday'] = pd.DatetimeIndex(df1['date']).day_name()
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11088\1277653125.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['weekday_number'] = pd.DatetimeIndex(df1['date']).weekday
#           city  unit_price customer_type  gender      total      payment  \
# 0       Yangon       74.69        Member  Female   548.9715      Ewallet
# 1    Naypyitaw       15.28        Normal  Female    80.2200         Cash
# 2       Yangon       46.33        Normal    Male   340.5255  Credit card
# 3       Yangon       58.22        Member    Male   489.0480      Ewallet
# 4       Yangon       86.31        Normal    Male   634.3785      Ewallet
# ..         ...         ...           ...     ...        ...          ...
# 995  Naypyitaw       40.35        Normal    Male    42.3675      Ewallet
# 996   Mandalay       97.38        Normal  Female  1022.4900      Ewallet
# 997     Yangon       31.84        Member    Male    33.4320         Cash
# 998     Yangon       65.82        Normal    Male    69.1110         Cash
# 999     Yangon       88.34        Member  Female   649.2990         Cash
#
#           date     month   weekday  weekday_number
# 0   2019-01-05   January  Saturday               5
# 1   2019-03-08     March    Friday               4
# 2   2019-03-03     March    Sunday               6
# 3   2019-01-27   January    Sunday               6
# 4   2019-02-08  February    Friday               4
# ..         ...       ...       ...             ...
# 995 2019-01-29   January   Tuesday               1
# 996 2019-03-02     March  Saturday               5
# 997 2019-02-09  February  Saturday               5
# 998 2019-02-22  February    Friday               4
# 999 2019-02-18  February    Monday               0
#
# [1000 rows x 10 columns]

# %%
gender_sum = df1.groupby(['gender'],as_index=False).agg({'total':'sum'}).rename(columns={'total':'sum'})

# %%
gender_sum
# Out:
#    gender         sum
# 0  Female  167882.925
# 1    Male  155083.824

# %%
city_sum = df1.groupby(['city'],as_index=False).agg({'total':'sum'}).rename(columns={'total':'sum'})

# %%
city_sum.sort_values('sum',ascending=False)
# Out:
#         city          sum
# 1  Naypyitaw  110568.7065
# 2     Yangon  106200.3705
# 0   Mandalay  106197.6720

# %%
sns.histplot(data= df1, x= 'total',)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
df1.describe()
# Out:
#         unit_price        total                        date        month
# count  1000.000000  1000.000000                        1000  1000.000000
# mean     55.672130   322.966749  2019-02-14 00:05:45.600000     1.993000
# min      10.080000    10.678500         2019-01-01 00:00:00     1.000000
# 25%      32.875000   124.422375         2019-01-24 00:00:00     1.000000
# 50%      55.230000   253.848000         2019-02-13 00:00:00     2.000000
# 75%      77.935000   471.350250         2019-03-08 00:00:00     3.000000
# max      99.960000  1042.650000         2019-03-30 00:00:00     3.000000
# std      26.494628   245.885335                         NaN     0.835254

# %%
sns.histplot(df1, x= 'total',  hue="gender",multiple='stack',fill = False)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
df1.groupby('payment',as_index=False).agg({'customer_type':'count', 'total' : 'sum'}).rename(columns = {'customer_type' : 'count', 'total' : 'sum'}).sort_values('sum',ascending = False)
# Out:
#        payment  count         sum
# 0         Cash    344  112206.570
# 2      Ewallet    345  109993.107
# 1  Credit card    311  100767.072

# %%
rating_weekday = df1.groupby(['month','weekday'] , as_index= False).agg({'total' : 'sum'}).rename(columns = {'total' : 'sum'}).sort_values(['month', 'weekday'], ascending= False)
rating_weekday
# Out:
#        month    weekday         sum
# 20     March  Wednesday  13517.2275
# 19     March    Tuesday  17611.3350
# 18     March   Thursday  12759.8100
# 17     March     Sunday  13470.1560
# 16     March   Saturday  25770.9270
# 15     March     Monday  10421.4915
# 14     March     Friday  15904.5600
# 13   January  Wednesday  17808.3780
# 12   January    Tuesday  21204.5085
# 11   January   Thursday  19416.3795
# 10   January     Sunday  14356.7550
# 9    January   Saturday  18093.6840
# 8    January     Monday  14192.6715
# 7    January     Friday  11219.4915
# 6   February  Wednesday  12405.5295
# 5   February    Tuesday  12666.4020
# 4   February   Thursday  13173.0585
# 3   February     Sunday  16630.9815
# 2   February   Saturday  12256.1985
# 1   February     Monday  13284.9150
# 0   February     Friday  16802.2890

# %%
sns.barplot(rating_weekday,x = 'weekday', y = 'sum', hue = 'month')
# Out:
# <Axes: xlabel='weekday', ylabel='sum'>
