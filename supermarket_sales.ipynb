# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

path_to_file = r'D:\university\VSCODE\project\Supermarket_sales\supermarket_sales.csv'

sns.set_style("dark")
sns.set_palette("Paired")
# Out:
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11916\2920147473.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv(path_to_file)
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# CHECK DUPLICATED ROWS
df.duplicated().any()
# Out:
# False

# %%
pd.DataFrame({'count': df.shape[0], 
              'nulls': df.isnull().sum(), 
              'nulls%': df.isnull().mean() * 100, 
              'cardinality': df.nunique(),
             })
# Out:
#                          count  nulls  nulls%  cardinality
# Invoice ID                1000      0     0.0         1000
# Branch                    1000      0     0.0            3
# City                      1000      0     0.0            3
# Customer type             1000      0     0.0            2
# Gender                    1000      0     0.0            2
# Product line              1000      0     0.0            6
# Unit price                1000      0     0.0          943
# Quantity                  1000      0     0.0           10
# Tax 5%                    1000      0     0.0          990
# Total                     1000      0     0.0          990
# Date                      1000      0     0.0           89
# Time                      1000      0     0.0          506
# Payment                   1000      0     0.0            3
# cogs                      1000      0     0.0          990
# gross margin percentage   1000      0     0.0            1
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.dtypes
# Out:
# Invoice ID                  object
# Branch                      object
# City                        object
# Customer type               object
# Gender                      object
# Product line                object
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Total                      float64
# Date                        object
# Time                        object
# Payment                     object
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Time'] = pd.to_datetime(df['Time'])
df.dtypes
# Out:
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11916\2964515701.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Time'] = pd.to_datetime(df['Time'])
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
def rename_columns(name):
    new_name = name.lower().replace(' ','_')
    return new_name

# %%
df.rename(columns= rename_columns,inplace=True)

# %%
df
# Out:
#       invoice_id branch       city customer_type  gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                product_line  unit_price  quantity   tax_5%      total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df1 = df[['city','gender','total','date','payment','time','product_line']]
df1['month'] = pd.DatetimeIndex(df1['date']).month_name()
df1['weekday'] = pd.DatetimeIndex(df1['date']).day_name()
df1['weekday_number'] = pd.DatetimeIndex(df1['date']).weekday
df1['hour'] = pd.DatetimeIndex(df1['time']).hour
# df1["Hours"] = df1["time"].apply(lambda x: x.hour)
df1['week'] = df1['date'].dt.strftime('%U').astype(int)

df1
# Приведение даты в месяц и в день недели
# Out:
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11916\2288206998.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['month'] = pd.DatetimeIndex(df1['date']).month_name()
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11916\2288206998.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['weekday'] = pd.DatetimeIndex(df1['date']).day_name()
# C:\Users\vnaumq\AppData\Local\Temp\ipykernel_11916\2288206998.py:4: SettingWithCopyWarning:
# ...

# %%
count_week = df1.week.value_counts().reset_index().sort_values('week').reset_index().drop('index',axis=1)
count_week
# Out:
#     week  count
# 0      0     46
# 1      1     72
# 2      2     82
# 3      3     89
# 4      4     83
# 5      5     95
# 6      6     70
# 7      7     64
# 8      8     82
# 9      9     90
# 10    10     84
# 11    11     71
# 12    12     72

# %%
gender_sum = df1.groupby(['gender'],as_index=False).agg({'total':'sum'}).rename(columns={'total':'sum'})

# %%
gender_sum
# Out:
#    gender         sum
# 0  Female  167882.925
# 1    Male  155083.824

# %%
city_sum = df1.groupby(['city'],as_index=False).agg({'total':'sum'}).rename(columns={'total':'sum'})

# %%
city_sum.sort_values('sum',ascending=False)
# Out:
#         city          sum
# 1  Naypyitaw  110568.7065
# 2     Yangon  106200.3705
# 0   Mandalay  106197.6720

# %%
sns.histplot(data= df1, x= 'total',)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
df1.describe()
# Out:
#              total                        date                        time  \
# count  1000.000000                        1000                        1000
# mean    322.966749  2019-02-14 00:05:45.600000  2024-03-17 15:24:41.880000
# min      10.678500         2019-01-01 00:00:00         2024-03-17 10:00:00
# 25%     124.422375         2019-01-24 00:00:00         2024-03-17 12:43:00
# 50%     253.848000         2019-02-13 00:00:00         2024-03-17 15:19:00
# 75%     471.350250         2019-03-08 00:00:00         2024-03-17 18:15:00
# max    1042.650000         2019-03-30 00:00:00         2024-03-17 20:59:00
# std     245.885335                         NaN                         NaN
#
#        weekday_number         hour        week
# count     1000.000000  1000.000000  1000.00000
# mean         3.032000    14.910000     6.12900
# min          0.000000    10.000000     0.00000
# 25%          1.000000    12.000000     3.00000
# 50%          3.000000    15.000000     6.00000
# ...

# %%
sns.histplot(df1, x= 'total',  hue="gender",multiple='stack',fill = False)
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %%
payment = df1.groupby('payment',as_index=False).agg({'gender':'count', 'total' : 'sum'}).rename(columns = {'gender' : 'count', 'total' : 'sum'}).sort_values('sum',ascending = False).rename(columns = {'sum' : 'revenue'})
payment
# Out:
#        payment  count     revenue
# 0         Cash    344  112206.570
# 2      Ewallet    345  109993.107
# 1  Credit card    311  100767.072

# %%
fig, ax = plt.subplots()
expold = (0.07, 0.01, 0.01)
ax.pie(payment.revenue, labels=payment.payment, autopct='%1.1f%%', explode=expold ,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1c03eea8dd0>,
# ...
#  [Text(-1.0381458402881236, 0.5395861509457649, 'Cash'),
#   Text(0.12326095298735701, -1.1031349588643489, 'Ewallet'),
#   Text(0.9219701415701533, 0.6181189675564984, 'Credit card')],
#  [Text(-0.5944937717889255, 0.30899377874672, '34.7%'),
#   Text(0.06773800119125024, -0.6062273197362638, '34.1%'),
#   Text(0.5066682759980121, 0.33968700018870635, '31.2%')])

# %%
rating_weekday = df1.groupby(['month','weekday','weekday_number'] , as_index= False).agg({'total' : 'sum'}).rename(columns = {'total' : 'revenue'}).sort_values(['month', 'weekday_number'])
rating_weekday
# Out:
#        month    weekday  weekday_number     revenue
# 1   February     Monday               0  13284.9150
# 5   February    Tuesday               1  12666.4020
# 6   February  Wednesday               2  12405.5295
# 4   February   Thursday               3  13173.0585
# 0   February     Friday               4  16802.2890
# 2   February   Saturday               5  12256.1985
# 3   February     Sunday               6  16630.9815
# 8    January     Monday               0  14192.6715
# 12   January    Tuesday               1  21204.5085
# 13   January  Wednesday               2  17808.3780
# 11   January   Thursday               3  19416.3795
# 7    January     Friday               4  11219.4915
# 9    January   Saturday               5  18093.6840
# 10   January     Sunday               6  14356.7550
# 15     March     Monday               0  10421.4915
# 19     March    Tuesday               1  17611.3350
# 20     March  Wednesday               2  13517.2275
# ...

# %%
sns.barplot(rating_weekday,x = 'weekday', y = 'revenue', hue = 'month')
# Out:
# <Axes: xlabel='weekday', ylabel='revenue'>

# %%
revenue_hour = df1.groupby(['month','hour'],as_index=False).agg({'total' : 'sum'}).rename(columns={'total':'revenue'})
revenue_hour
# Out:
#        month  hour     revenue
# 0   February    10  10579.0335
# 1   February    11  11118.6600
# 2   February    12   7138.8345
# 3   February    13   7367.8080
# 4   February    14   8531.1450
# 5   February    15  11131.0080
# 6   February    16   8752.0545
# 7   February    17   7833.8400
# 8   February    18   8961.0780
# 9   February    19   9018.1245
# 10  February    20   6787.7880
# 11   January    10  12357.2295
# 12   January    11  12510.2460
# 13   January    12   8767.7415
# 14   January    13  15700.3980
# 15   January    14  10815.3360
# 16   January    15  11798.2305
# 17   January    16   7306.0890
# 18   January    17   7794.7485
# 19   January    18   8467.0635
# 20   January    19  10932.6945
# 21   January    20   9842.0910
# 22     March    10   8485.2180
# 23     March    11   6748.4235
# 24     March    12  10159.3065
# 25     March    13  11655.0210
# 26     March    14  11481.9180
# 27     March    15   8250.2700
# 28     March    16   9168.1800
# ...

# %%
sns.lineplot(revenue_hour,x='hour',y='revenue',hue='month',style="month")
# Out:
# <Axes: xlabel='hour', ylabel='revenue'>

# %%
what = df1.query('hour == 19 and month == "March"').total.count()
what
# Out:
# 52

# %%
revenue_week = df1.groupby('week').agg({'total':'sum'}).reset_index().rename(columns={'total':'revenue'})
revenue_week
# Out:
#     week     revenue
# 0      0  13929.1845
# 1      1  25624.2000
# 2      2  27489.1155
# 3      3  28306.4355
# 4      4  27528.4170
# 5      5  29428.7385
# 6      6  23405.0460
# 7      7  19905.7740
# 8      8  27089.0025
# 9      9  30108.7815
# 10    10  25177.1625
# 11    11  23619.4245
# 12    12  21355.4670

# %%
sns.lineplot(revenue_week,x='week',y='revenue',marker='o',markerfacecolor = 'black')
# Out:
# <Axes: xlabel='week', ylabel='revenue'>

# %%
product_revenue = df1.groupby('product_line',as_index=False).agg({'total' : 'sum'}).rename(columns={'total':'revenue'}).sort_values('revenue',ascending=False)
product_revenue.set_index('product_line',inplace=True)
product_revenue
# Out:
#                            revenue
# product_line
# Food and beverages      56144.8440
# Sports and travel       55122.8265
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Home and lifestyle      53861.9130
# Health and beauty       49193.7390

# %%
product_revenue.plot.pie(y='revenue',figsize=(7,7))
# Out:
# <Axes: ylabel='revenue'>

# %%
fig, ax = plt.subplots()
ax.pie(product_revenue.revenue, labels=product_revenue.index, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2356a97d550>,
# ...
#  [Text(0.9399907865232462, 0.5713294332094306, 'Food and beverages'),
#   Text(-0.06340678822092591, 1.0981710154650353, 'Sports and travel'),
#   Text(-0.9912710276469388, 0.4768456246499302, 'Electronic accessories'),
#   Text(-0.9025960654028014, -0.6287450538329363, 'Fashion accessories'),
#   Text(0.0986710869916935, -1.0955656149185578, 'Home and lifestyle'),
#   Text(0.9764441324952551, -0.5065144184676176, 'Health and beauty')],
#  [Text(0.5127222471944979, 0.3116342362960531, '17.4%'),
#   Text(-0.03458552084777776, 0.5990023720718374, '17.1%'),
#   Text(-0.5406932878074211, 0.26009761344541643, '16.8%'),
#   Text(-0.49232512658334615, -0.342951847545238, '16.8%'),
#   Text(0.05382059290456008, -0.5975812445010314, '16.7%'),
#   Text(0.5326058904519573, -0.27628059189142773, '15.2%')])

# %%
explode = (0.07, 0.01, 0.01, 0.01, 0.01, 0.01)
fig, ax = plt.subplots()
ax.pie(product_revenue.revenue, labels=product_revenue.index, autopct='%1.1f%%', explode=explode,startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x2356a9d8320>,
# ...
#  [Text(-0.6076867607773033, 0.9998083820292709, 'Food and beverages'),
#   Text(-1.1081543883328993, -0.0639832135683888, 'Sports and travel'),
#   Text(-0.48118058487402054, -1.0002825824437291, 'Electronic accessories'),
#   Text(0.6344609179586908, -0.9108014841791903, 'Fashion accessories'),
#   Text(1.1055253023269083, 0.09956809687343608, 'Home and lifestyle'),
#   Text(0.5111190949991414, 0.985320897336121, 'Health and beauty')],
#  [Text(-0.3479915638639258, 0.5725398427005226, '17.4%'),
#   Text(-0.6089857449397014, -0.035161946195240684, '17.1%'),
#   Text(-0.2644325736695068, -0.5497048426042115, '16.8%'),
#   Text(0.34866771167099214, -0.5005305453597352, '16.8%'),
#   Text(0.607540931909382, 0.05471760278630271, '16.7%'),
#   Text(0.2808852684229516, 0.5414826552928232, '15.2%')])

# %%
product_line_week = df1.groupby(['week','product_line']).agg({'total':'sum'}).reset_index().rename(columns={'total':'revenue'})
product_line_week
# Out:
#     week            product_line    revenue
# 0      0  Electronic accessories  2917.0470
# 1      0     Fashion accessories  2026.4475
# 2      0      Food and beverages  1403.2410
# 3      0       Health and beauty  2960.1495
# 4      0      Home and lifestyle  2642.8500
# ..   ...                     ...        ...
# 73    12     Fashion accessories  2657.7390
# 74    12      Food and beverages  3843.1470
# 75    12       Health and beauty  6175.1130
# 76    12      Home and lifestyle  2116.1385
# 77    12       Sports and travel  1798.0620
#
# [78 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
sns.lineplot(product_line_week,x='week',y='revenue',hue='product_line',style="product_line",)
# Out:
# <Axes: xlabel='week', ylabel='revenue'>

# %%
sns.relplot(
    data=product_line_week, x="week", y="revenue",
    col="product_line", hue="product_line", 
    kind="line",marker='o',col_wrap=3,sizes=(10, 10)
)
